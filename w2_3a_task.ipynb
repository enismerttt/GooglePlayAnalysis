# %% [markdown]
# a)plot a bar chart for the total prices of each paid app in each category

# %%
import pandas as pd
import matplotlib.pyplot as plt

ps = pd.read_csv('cleaned_playstore.csv')
paidapps = ps[ps.Type == "Paid"]
paidapps
# Out:
#       Unnamed: 0                                            App  \
# 233          233  TurboScan: scan documents and receipts in PDF
# 234          234                 Tiny Scanner Pro: PDF Doc Scan
# 372          372                             Puffin Browser Pro
# 406          406                      Moco+ - Chat, Meet People
# 407          407                                     Calculator
# ...          ...                                            ...
# 9556        9556                                    FP VoiceBot
# 9580        9580                                Fast Tract Diet
# 9601        9601                        Trine 2: Complete Story
# 9604        9604                                   sugar, sugar
# 9617        9617                           Word Search Tab 1 FR
#
#                 Category  Rating  Reviews          Size  Installs  Type  \
# 233             BUSINESS     4.7  11442.0  6.800000e+06  100000.0  Paid
# ...

# %%
paidapps.Category.value_counts().size
# Out:
# 30

# %%
pa = paidapps.groupby('Category').sum()['Price'].sort_values(ascending=False)
pa
# Out:
# C:\Users\Enis Mert Kiriş\AppData\Local\Temp\ipykernel_2848\3032104393.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pa = paidapps.groupby('Category').sum()['Price'].sort_values(ascending=False)
# Category
# FINANCE                2900.829931
# FAMILY                 2399.859955
# LIFESTYLE              2360.869952
# MEDICAL                 995.699992
# GAME                    284.309995
# TOOLS                   267.249996
# PRODUCTIVITY            250.930004
# BUSINESS                175.289996
# PERSONALIZATION         150.479999
# BOOKS_AND_REFERENCE     119.769996
# PHOTOGRAPHY             118.279999
# EVENTS                  109.989998
# SPORTS                  100.000000
# COMMUNICATION            83.139999
# HEALTH_AND_FITNESS       64.349999
# TRAVEL_AND_LOCAL         49.949999
# ...

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
plt.bar(pa.index, pa.values)
plt.show()
